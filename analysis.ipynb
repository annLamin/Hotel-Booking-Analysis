# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv('Results/cleaned_data.csv')

# %%
data.shape
# Out:
# (75203, 32)

# %%
data
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0         13               2015
# 1      Resort Hotel            0         14               2015
# 2      Resort Hotel            0          9               2015
# 3      Resort Hotel            1         85               2015
# 4      Resort Hotel            1         75               2015
# ...             ...          ...        ...                ...
# 75198    City Hotel            0         23               2017
# 75199    City Hotel            0        102               2017
# 75200    City Hotel            0         34               2017
# 75201    City Hotel            0        109               2017
# 75202    City Hotel            0        205               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# 1                   July                        27                          1
# 2                   July                        27                          1
# 3                   July                        27                          1
# 4                   July                        27                          1
# ...                  ...                       ...                        ...
# 75198             August                        35                         30
# 75199             August                        35                         31
# 75200             August                        35                         31
# 75201             August                        35                         31
# 75202             August                        35                         29
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                            0                     1       1  ...
# 1                            0                     2       2  ...
# 2                            0                     2       2  ...
# 3                            0                     3       2  ...
# 4                            0                     3       2  ...
# ...                        ...                   ...     ...  ...
# 75198                        2                     5       2  ...
# 75199                        2                     5       3  ...
# 75200                        2                     5       2  ...
# 75201                        2                     5       2  ...
# 75202                        2                     7       2  ...
#
#        deposit_type  agent days_in_waiting_list customer_type     adr  \
# 0        No Deposit    304                    0     Transient   75.00
# 1        No Deposit    240                    0     Transient   98.00
# 2        No Deposit    303                    0     Transient  103.00
# 3        No Deposit    240                    0     Transient   82.00
# 4        No Deposit     15                    0     Transient  105.50
# ...             ...    ...                  ...           ...     ...
# 75198    No Deposit    394                    0     Transient   96.14
# 75199    No Deposit      9                    0     Transient  225.43
# 75200    No Deposit      9                    0     Transient  157.71
# 75201    No Deposit     89                    0     Transient  104.40
# 75202    No Deposit      9                    0     Transient  151.20
#
#       required_car_parking_spaces  total_of_special_requests  \
# 0                               0                          0
# 1                               0                          1
# 2                               0                          1
# 3                               0                          1
# 4                               0                          0
# ...                           ...                        ...
# 75198                           0                          0
# 75199                           0                          2
# 75200                           0                          4
# 75201                           0                          0
# 75202                           0                          2
#
#        reservation_status  reservation_status_date arrival_date
# 0               Check-Out               2015-07-02   2015-07-01
# 1               Check-Out               2015-07-03   2015-07-01
# 2               Check-Out               2015-07-03   2015-07-01
# 3                Canceled               2015-05-06   2015-07-01
# 4                Canceled               2015-04-22   2015-07-01
# ...                   ...                      ...          ...
# 75198           Check-Out               2017-09-06   2017-08-30
# 75199           Check-Out               2017-09-07   2017-08-31
# 75200           Check-Out               2017-09-07   2017-08-31
# 75201           Check-Out               2017-09-07   2017-08-31
# 75202           Check-Out               2017-09-07   2017-08-29
#
# [75203 rows x 32 columns]

# %%
stats = data.describe().T
stats
# Out:
#                                   count         mean         std      min  \
# is_canceled                     75203.0     0.298765    0.457719     0.00
# lead_time                       75203.0    86.838171   85.955738     0.00
# arrival_date_year               75203.0  2016.225044    0.682790  2015.00
# arrival_date_week_number        75203.0    26.917703   13.370185     1.00
# arrival_date_day_of_month       75203.0    15.794809    8.845003     1.00
# stays_in_weekend_nights         75203.0     1.069638    1.032518     0.00
# stays_in_week_nights            75203.0     2.749837    2.042554     0.00
# adults                          75203.0     1.923873    0.519316     0.00
# children                        75203.0     0.148744    0.471272     0.00
# babies                          75203.0     0.010492    0.113263     0.00
# is_repeated_guest               75203.0     0.014614    0.120002     0.00
# previous_cancellations          75203.0     0.019680    0.315947     0.00
# previous_bookings_not_canceled  75203.0     0.033562    0.509964     0.00
# booking_changes                 75203.0     0.248089    0.697864     0.00
# agent                           75203.0    94.138306  113.188172     1.00
# days_in_waiting_list            75203.0     0.808851   10.564669     0.00
# adr                             75203.0   110.123521   54.404275    -6.38
# required_car_parking_spaces     75203.0     0.072377    0.260598     0.00
# total_of_special_requests       75203.0     0.739306    0.832475     0.00
#
#                                     25%     50%     75%     max
# is_canceled                        0.00     0.0     1.0     1.0
# lead_time                         18.00    59.0   134.0   629.0
# arrival_date_year               2016.00  2016.0  2017.0  2017.0
# arrival_date_week_number          16.00    28.0    37.0    53.0
# arrival_date_day_of_month          8.00    16.0    24.0    31.0
# stays_in_weekend_nights            0.00     1.0     2.0    16.0
# stays_in_week_nights               1.00     2.0     4.0    41.0
# adults                             2.00     2.0     2.0    26.0
# children                           0.00     0.0     0.0    10.0
# babies                             0.00     0.0     0.0    10.0
# is_repeated_guest                  0.00     0.0     0.0     1.0
# previous_cancellations             0.00     0.0     0.0    26.0
# previous_bookings_not_canceled     0.00     0.0     0.0    50.0
# booking_changes                    0.00     0.0     0.0    18.0
# agent                              9.00    14.0   240.0   535.0
# days_in_waiting_list               0.00     0.0     0.0   391.0
# adr                               75.95   101.5   136.8  5400.0
# required_car_parking_spaces        0.00     0.0     0.0     3.0
# total_of_special_requests          0.00     1.0     1.0     5.0

# %%
stats.to_csv('Results/Statistics11.csv', index=False)

# %%
corrmatrix = data.corr()
fig = plt.figure(figsize = (12, 9))

sns.heatmap(corrmatrix, vmax = .9, square = True)
plt.savefig('Results/correlation.pdf')
plt.show()

# %%
grouped_by_hotel = data.groupby('hotel')
data11 = pd.DataFrame((grouped_by_hotel.size()/data.shape[0])*100).reset_index().rename(columns = {0:'Booking %'})      #Calculating percentage
plt.figure(figsize = (8,5))
sns.barplot(x = data11['hotel'], y = data11['Booking %'] )
plt.savefig('Results/Barplot2.pdf')
plt.show()

# %%
grp_by_country = data.groupby('country')
data2 = pd.DataFrame(grp_by_country.size()).rename(columns = {0:'no. of bookings'}).sort_values('no. of bookings', ascending = False)
data2 = data2[:10]
sns.scatterplot(x = data2.index, y = data2['no. of bookings'])
plt.savefig('Results/Scatterplot2.pdf')
plt.show()

# %%
bar = pd.DataFrame(data['agent'].value_counts()).reset_index().rename(columns = {'index':'agent','agent':'num_of_bookings'}
                                                                   ).sort_values(by = 'num_of_bookings', ascending = False)
bar.drop(bar[bar['agent'] == 0].index, inplace = True)            # 0 represents that booking is not made by an agent
bar = bar[:10]                                                   # Selecting top 10 performing agents
plt.figure(figsize = (10,8))
sns.barplot(x = 'agent', y = 'num_of_bookings', data = bar, order = bar.sort_values('num_of_bookings', ascending = False).agent)
plt.savefig('Results/barplot.pdf')

# %%
data["booking_changes"].value_counts()
# Out:
# 0     62687
# 1      8565
# 2      2823
# 3       653
# 4       270
# 5        82
# 6        50
# 7        26
# 8        14
# 9         8
# 10        6
# 13        5
# 14        3
# 15        3
# 17        2
# 16        2
# 12        2
# 18        1
# 11        1
# Name: booking_changes, dtype: int64

# %%
total_booking_changes = data['booking_changes'].count()
total_booking_changes
# Out:
# 75203

# %%
df1.drop(df1[df1['adr'] > 5000].index, inplace = True)
months = ['January', 'February','March','April','May','June','July','August','September','October','November','December']
df1['arrival_date_month'] = pd.Categorical(df1['arrival_date_month'],categories=months,ordered=True)
plt.figure(figsize = (15,8))
sns.boxplot(x = df1['arrival_date_month'],y = df1['adr'])
plt.savefig('Results/boxplot1.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 df1 = data11
# ----> 2 df1.drop(df1[df1['adr'] > 5000].index, inplace = True)
#       3 months = ['January', 'February','March','April','May','June','July','August','September','October','November','December']
#       4 df1['arrival_date_month'] = pd.Categorical(df1['arrival_date_month'],categories=months,ordered=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'adr'

# %%
sorted_months = data.arrival_date_month.value_counts().reindex(months)
x = sorted_months.index
y = sorted_months/sorted_months.sum()*100
plt.figure(figsize=(15,8))
plt.xlabel('Months')
plt.ylabel('Booking (%)')
plt.title('Monthly booking trend')
plt.plot(x, y)
plt.grid()
plt.savefig('Results/lineplot.pdf')
plt.show()
